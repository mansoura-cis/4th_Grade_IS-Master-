# %%
import pandas as pd

# %%
myFile = pd.read_csv("Employees.csv")

# %%
myFile
# Out:
#          Employee       Hired   Salary  Sick Days
# 0  Graham Chapman  2014-03-15  50000.0         10
# 1     John Cleese  2015-06-01  65000.0          8
# 2       Eric Idle  2014-05-12  45000.0         10
# 3     Terry Jones  2013-11-01  70000.0          3
# 4   Terry Gilliam  2014-08-12  48000.0          7
# 5   Michael Palin  2013-05-23  66000.0          8

# %%
myquery = myFile.query("Salary > 50000")

# %%
myquery
# Out:
#         Employee       Hired   Salary  Sick Days
# 1    John Cleese  2015-06-01  65000.0          8
# 3    Terry Jones  2013-11-01  70000.0          3
# 5  Michael Palin  2013-05-23  66000.0          8

# %%
myFile["Salary"].hist()

# %%
myFile.boxplot(column='Salary')

# %%
myFile["Salary"].mean()
# Out:
# 57333.333333333336

# %%
myExcel = pd.read_excel("SampleData.xlsx",sheetname="SalesOrders")

# %%
myExcel
# Out:
#     OrderDate   Region       Rep     Item  Units  Unit Cost    Total
# 0  2018-01-06     East     Jones   Pencil     95       1.99   189.05
# 1  2018-01-23  Central    Kivell   Binder     50      19.99   999.50
# 2  2018-02-09  Central   Jardine   Pencil     36       4.99   179.64
# 3  2018-02-26  Central      Gill      Pen     27      19.99   539.73
# 4  2018-03-15     West   Sorvino   Pencil     56       2.99   167.44
# 5  2018-04-01     East     Jones   Binder     60       4.99   299.40
# 6  2018-04-18  Central   Andrews   Pencil     75       1.99   149.25
# 7  2018-05-05  Central   Jardine   Pencil     90       4.99   449.10
# 8  2018-05-22     West  Thompson   Pencil     32       1.99    63.68
# 9  2018-06-08     East     Jones   Binder     60       8.99   539.40
# 10 2018-06-25  Central    Morgan   Pencil     90       4.99   449.10
# 11 2018-07-12     East    Howard   Binder     29       1.99    57.71
# 12 2018-07-29     East    Parent   Binder     81      19.99  1619.19
# ...

# %%
myExcel["Item"]
# Out:
# 0      Pencil
# 1      Binder
# 2      Pencil
# 3         Pen
# 4      Pencil
# 5      Binder
# 6      Pencil
# 7      Pencil
# 8      Pencil
# 9      Binder
# 10     Pencil
# 11     Binder
# 12     Binder
# 13     Pencil
# 14       Desk
# 15    Pen Set
# 16     Binder
# 17        Pen
# 18        Pen
# 19    Pen Set
# 20     Pencil
# 21    Pen Set
# 22     Binder
# 23     Binder
# 24     Binder
# 25     Binder
# 26    Pen Set
# 27     Pencil
# 28        Pen
# 29     Pencil
# 30     Binder
# 31       Desk
# 32    Pen Set
# 33    Pen Set
# 34    Pen Set
# 35       Desk
# 36     Pencil
# 37        Pen
# 38     Binder
# 39     Pencil
# 40     Binder
# 41     Binder
# 42     Binder
# Name: Item, dtype: object

# %%
myExcel["Total"].hist()

# %%
myExcel[["Item","Total","Rep"]]
# Out:
#        Item    Total       Rep
# 0    Pencil   189.05     Jones
# 1    Binder   999.50    Kivell
# 2    Pencil   179.64   Jardine
# 3       Pen   539.73      Gill
# 4    Pencil   167.44   Sorvino
# 5    Binder   299.40     Jones
# 6    Pencil   149.25   Andrews
# 7    Pencil   449.10   Jardine
# 8    Pencil    63.68  Thompson
# 9    Binder   539.40     Jones
# 10   Pencil   449.10    Morgan
# 11   Binder    57.71    Howard
# 12   Binder  1619.19    Parent
# 13   Pencil   174.65     Jones
# 14     Desk   250.00     Smith
# 15  Pen Set   255.84     Jones
# 16   Binder   251.72    Morgan
# 17      Pen   575.36     Jones
# 18      Pen   299.85    Parent
# 19  Pen Set   479.04    Kivell
# 20   Pencil    86.43     Smith
# 21  Pen Set  1183.26    Parent
# 22   Binder   413.54      Gill
# 23   Binder  1305.00     Smith
# 24   Binder    19.96     Jones
# 25   Binder   139.93   Sorvino
# 26  Pen Set   249.50   Jardine
# 27   Pencil   131.34   Andrews
# 28      Pen   479.04    Howard
# ...
